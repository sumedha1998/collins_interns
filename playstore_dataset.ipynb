# %%
import pandas as pd
#used to read csv file
df=pd.read_csv("C:/Users/sraghu1/python/gps.csv")
#displays the first 100 values
df.head(100)
#decription of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# describe displays data of each numerical feature
print(df.describe())
df["Reviews"].describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000
# count     10841
# unique     6002
# top           0
# freq        596
# Name: Reviews, dtype: object

# %%
df1=pd.DataFrame(df)
#displays the column header 
print(df1.columns.values)
# Out:
# ['App' 'Category' 'Rating' 'Reviews' 'Size' 'Installs' 'Type' 'Price'
#  'Content Rating' 'Genres' 'Last Updated' 'Current Ver' 'Android Ver']

# %%
#used to display count of each object of a column
df['Category'].value_counts()
#to caculate the fraction amount
df['Category'].value_counts(normalize=True)
# Out:
# FAMILY                 0.181902
# GAME                   0.105525
# TOOLS                  0.077760
# MEDICAL                0.042708
# BUSINESS               0.042432
# PRODUCTIVITY           0.039111
# PERSONALIZATION        0.036159
# COMMUNICATION          0.035698
# SPORTS                 0.035421
# LIFESTYLE              0.035237
# FINANCE                0.033761
# HEALTH_AND_FITNESS     0.031455
# PHOTOGRAPHY            0.030901
# SOCIAL                 0.027212
# NEWS_AND_MAGAZINES     0.026105
# SHOPPING               0.023983
# TRAVEL_AND_LOCAL       0.023799
# DATING                 0.021585
# BOOKS_AND_REFERENCE    0.021308
# VIDEO_PLAYERS          0.016142
# EDUCATION              0.014390
# ENTERTAINMENT          0.013744
# MAPS_AND_NAVIGATION    0.012637
# FOOD_AND_DRINK         0.011715
# HOUSE_AND_HOME         0.008117
# LIBRARIES_AND_DEMO     0.007841
# AUTO_AND_VEHICLES      0.007841
# WEATHER                0.007564
# ART_AND_DESIGN         0.005996
# ...

# %%
#sort in ascending order of category and descending order of rating
df1.sort_values(by=["Category","Rating"],ascending=[True,False])
# Out:
#                                                      App        Category  \
# 10472            Life Made WI-Fi Touchscreen Photo Frame             1.9
# 8888             Spring flowers theme couleurs d t space  ART_AND_DESIGN
# 25                            Harley Quinn wallpapers HD  ART_AND_DESIGN
# 3982                                   Cardi B Wallpaper  ART_AND_DESIGN
# 4759   X Launcher Pro - IOS Style Theme & Control Center  ART_AND_DESIGN
# ...                                                  ...             ...
# 6434                                         Skywatch BL         WEATHER
# 7332                                     Weather Data CH         WEATHER
# 10612                  Clearwater, FL - weather and more         WEATHER
# 10625              St. Petersburg, FL - weather and more         WEATHER
# 10627          WSVN • South Florida's Source for Weather         WEATHER
#
#        Rating Reviews                Size Installs  Type     Price  \
# ...

# %%
print(df["Rating"].mean())
#max of rating 4.8 and reviews
df1[df1["Rating"]==4.8]["Reviews"].max()
# Out:
# 4.193338315362448
# '97'

# %%
#index by column name
df1.loc[0:5,"App":"Rating"]
# Out:
#                                                  App        Category  Rating
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4

# %%
#index by column no.
df1.iloc[0:5,0:3]
# Out:
#                                                  App        Category  Rating
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3

# %%
#searching a particular value using lambda function

df1[df1["App"].apply(lambda App: App[0]=='z')]
# Out:
#                                                 App  Category  Rating Reviews  \
# 2758  zulily - Shop Daily Deals in Fashion and Home  SHOPPING     4.5   28560
#
#                     Size    Installs  Type Price Content Rating    Genres  \
# 2758  Varies with device  1,000,000+  Free     0       Everyone  Shopping
#
#        Last Updated         Current Ver         Android Ver
# 2758  July 23, 2018  Varies with device  Varies with device

# %%
df1[df1["App"].apply(lambda App: App=="Quiz DC")]
# Out:
#           App Category  Rating Reviews  Size Installs  Type Price  \
# 8258  Quiz DC     GAME     1.4      33  3.1M   1,000+  Free     0
#
#      Content Rating  Genres       Last Updated Current Ver Android Ver
# 8258       Everyone  Trivia  December 25, 2017        1.10  4.1 and up

# %%
#prints the duplicated value except the first occurance of all particular column
df2=df1[df1.duplicated()]
df2
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
#prints the duplicated value except the first occurance of a particular column
df2=df1[df1.duplicated("Last Updated")]
df2
# Out:
#                                                  App             Category  \
# 16      Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 18                     FlipaClip - Cartoon animation       ART_AND_DESIGN
# 28                             Pencil Sketch Drawing       ART_AND_DESIGN
# 30                    Pink Silver Bow Keyboard Theme       ART_AND_DESIGN
# 41                      Sad Poetry Photo Frames 2018       ART_AND_DESIGN
# ...                                              ...                  ...
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# ...

# %%
#checks which columns contain null values
df1.columns[df1.isnull().any()]
# Out:
# Index(['Rating', 'Type', 'Content Rating', 'Current Ver', 'Android Ver'], dtype='object')

# %%
null_columns=df.columns[df.isnull().any()]
print("the amount of null values in each column")
df[null_columns].isnull().sum()
# Out:
# the amount of null values in each column
# Rating            1474
# Type                 1
# Content Rating       1
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
print(" null values in a particular column like rating")
df[df["Rating"].isnull()][null_columns]
# Out:
#  null values in a particular column like rating
#        Rating  Type Content Rating Current Ver Android Ver
# 23        NaN  Free       Everyone       1.0.0  4.1 and up
# 113       NaN  Free   Everyone 10+         8.0  3.0 and up
# 123       NaN  Free       Everyone         1.3  4.1 and up
# 126       NaN  Free           Teen        1.15  4.1 and up
# 129       NaN  Free     Mature 17+         2.0  2.3 and up
# ...       ...   ...            ...         ...         ...
# 10824     NaN  Free       Everyone       2.2.2  4.4 and up
# 10825     NaN  Free           Teen         1.0  4.0 and up
# 10831     NaN  Free       Everyone   2.0.148.0  4.0 and up
# 10835     NaN  Free       Everyone       1.1.5  4.0 and up
# 10838     NaN  Free       Everyone         1.0  2.2 and up
#
# [1474 rows x 5 columns]

# %%
# Seaborn is a Python data visualization library based on matplotlib. 
import seaborn as sns
sns.boxplot(x=df1['Rating'])

# %%
import matplotlib.pyplot as plt
fig_dims = (500,20)
fig, ax = plt.subplots(figsize=fig_dims)


sns.countplot(x="Genres",hue="Content Rating",data=df)

# %%
#cleaning the data
to_drop = ['Content Rating','Android Ver']
df1.drop(to_drop,inplace=True,axis=1)
#print(df.columns.values)

# %%
print(df1.columns.values)
# Out:
# ['App' 'Category' 'Rating' 'Reviews' 'Size' 'Installs' 'Type' 'Price'
#  'Genres' 'Last Updated' 'Current Ver']

# %%
df1["Reviews"].is_unique
# Out:
# False

# %%
d={"ART_AND_DESIGN":"ART"}
df1["Category"]=df1["Category"].map(d)

# %%
df1["Category"]
# Out:
# 0        ART
# 1        ART
# 2        ART
# 3        ART
# 4        ART
#         ...
# 10836    NaN
# 10837    NaN
# 10838    NaN
# 10839    NaN
# 10840    NaN
# Name: Category, Length: 10841, dtype: object

# %%
df["Category"]
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10841, dtype: object
